# %%
import pandas

df = pandas.read_json('magazine.json')
df
# Out:
#                                               title  \
# 0                           人材紹介の売上が4倍に？入社決定率の重要性とは
# 1     新型コロナウイルスで求人数が激減する？今後の採用市場の見通しと人材紹介会社が今とるべき対策
# 2                          人材紹介会社の起業完全ガイド【2020年最新版】
# 3                                              None
# 4                       外国人の人材紹介における「ビザ」と「日本語能力」の問題
# 5   資金繰りを改善する！クラウド求人データベースagent bankの紹介手数料前払いサービスとは
# 6                          立ち上げたばかりの人材紹介事業…売上が伸びない？
# 7    【agent bank導入事例】紹介事業の月間売上約200万円をagent bankで実現！
# 8                            【小規模人材紹介会社向け】求人開拓完全ガイド
# 9                     実はこのように二極化していた！最新の人材紹介マーケット事情
# 10              AIに仕事を奪われる人材エージェントと価値が上昇するエージェントの違い
#
#                                                   url
# 0   https://sardine-system.com/media/categories/la...
# 1   https://sardine-system.com/media/categories/co...
# 2   https://sardine-system.com/media/categories/la...
# 3   https://agent-bank.com/?utm_source=magazine&ut...
# 4   https://sardine-system.com/media/categories/st...
# ...
